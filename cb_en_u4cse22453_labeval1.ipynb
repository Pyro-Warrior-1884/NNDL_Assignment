# %%
import numpy as np
import pandas as pd

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-624151bb-f88a-4dc7-ac86-e4cbfa297e9a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-624151bb-f88a-4dc7-ac86-e4cbfa297e9a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !mkdir -p ~/.kaggle
# !mv kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d uciml/adult-census-income
# Out:
# Dataset URL: https://www.kaggle.com/datasets/uciml/adult-census-income
# License(s): CC0-1.0
# ...
#   0% 0.00/450k [00:00<?, ?B/s]
# 100% 450k/450k [00:00<00:00, 693MB/s]

# %%
# !unzip adult-census-income.zip
# Out:
# Archive:  adult-census-income.zip
#   inflating: adult.csv

# %%
df=pd.read_csv('adult.csv')
df
# Out:
#        age workclass  fnlwgt     education  education.num      marital.status  \
# 0       90         ?   77053       HS-grad              9             Widowed
# 1       82   Private  132870       HS-grad              9             Widowed
# 2       66         ?  186061  Some-college             10             Widowed
# 3       54   Private  140359       7th-8th              4            Divorced
# 4       41   Private  264663  Some-college             10           Separated
# ...    ...       ...     ...           ...            ...                 ...
# 32556   22   Private  310152  Some-college             10       Never-married
# 32557   27   Private  257302    Assoc-acdm             12  Married-civ-spouse
# 32558   40   Private  154374       HS-grad              9  Married-civ-spouse
# 32559   58   Private  151910       HS-grad              9             Widowed
# 32560   22   Private  201490       HS-grad              9       Never-married
#
# ...

# %%
df1=df
df1
# Out:
#        age workclass  fnlwgt     education  education.num      marital.status  \
# 0       90         ?   77053       HS-grad              9             Widowed
# 1       82   Private  132870       HS-grad              9             Widowed
# 2       66         ?  186061  Some-college             10             Widowed
# 3       54   Private  140359       7th-8th              4            Divorced
# 4       41   Private  264663  Some-college             10           Separated
# ...    ...       ...     ...           ...            ...                 ...
# 32556   22   Private  310152  Some-college             10       Never-married
# 32557   27   Private  257302    Assoc-acdm             12  Married-civ-spouse
# 32558   40   Private  154374       HS-grad              9  Married-civ-spouse
# 32559   58   Private  151910       HS-grad              9             Widowed
# 32560   22   Private  201490       HS-grad              9       Never-married
#
# ...

# %%
df1.dropna(inplace=True) #drop null
df1
# Out:
#        age workclass  fnlwgt     education  education.num      marital.status  \
# 0       90         ?   77053       HS-grad              9             Widowed
# 1       82   Private  132870       HS-grad              9             Widowed
# 2       66         ?  186061  Some-college             10             Widowed
# 3       54   Private  140359       7th-8th              4            Divorced
# 4       41   Private  264663  Some-college             10           Separated
# ...    ...       ...     ...           ...            ...                 ...
# 32556   22   Private  310152  Some-college             10       Never-married
# 32557   27   Private  257302    Assoc-acdm             12  Married-civ-spouse
# 32558   40   Private  154374       HS-grad              9  Married-civ-spouse
# 32559   58   Private  151910       HS-grad              9             Widowed
# 32560   22   Private  201490       HS-grad              9       Never-married
#
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(24)

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#        age workclass  fnlwgt     education  education.num      marital.status  \
# 0       90         ?   77053       HS-grad              9             Widowed
# 1       82   Private  132870       HS-grad              9             Widowed
# 2       66         ?  186061  Some-college             10             Widowed
# 3       54   Private  140359       7th-8th              4            Divorced
# 4       41   Private  264663  Some-college             10           Separated
# ...    ...       ...     ...           ...            ...                 ...
# 32556   22   Private  310152  Some-college             10       Never-married
# 32557   27   Private  257302    Assoc-acdm             12  Married-civ-spouse
# 32558   40   Private  154374       HS-grad              9  Married-civ-spouse
# 32559   58   Private  151910       HS-grad              9             Widowed
# 32560   22   Private  201490       HS-grad              9       Never-married
#
# ...

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#        age workclass  fnlwgt     education  education.num      marital.status  \
# 0       90         ?   77053       HS-grad              9             Widowed
# 1       82   Private  132870       HS-grad              9             Widowed
# 2       66         ?  186061  Some-college             10             Widowed
# 3       54   Private  140359       7th-8th              4            Divorced
# 4       41   Private  264663  Some-college             10           Separated
# ...    ...       ...     ...           ...            ...                 ...
# 32556   22   Private  310152  Some-college             10       Never-married
# 32557   27   Private  257302    Assoc-acdm             12  Married-civ-spouse
# 32558   40   Private  154374       HS-grad              9  Married-civ-spouse
# 32559   58   Private  151910       HS-grad              9             Widowed
# 32560   22   Private  201490       HS-grad              9       Never-married
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder,StandardScaler
from sklearn.model_selection import train_test_split

# %%
cat_cols = df.select_dtypes(include='object').columns
label_encoders = {}

for col in cat_cols:
    le=LabelEncoder()
    df[col]=le.fit_transform(df[col])
    label_encoders[col]=le

X=df.drop('income', axis=1)
y=df['income']
scaler=StandardScaler()
X_scaled=scaler.fit_transform(X)
X_train,X_test,y_train,y_test=train_test_split(X_scaled,y,test_size=0.2,random_state=42)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
model = Sequential([Dense(64, input_dim=X_train.shape[1], activation='relu'),Dropout(0.3),Dense(32, activation='relu'),Dense(1, activation='sigmoid')])
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
history = model.fit(X_train, y_train, validation_split=0.2,epochs=25, batch_size=32,verbose=1)
# Out:
# Epoch 1/25
# 651/651 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8634 - loss: 0.3012 - val_accuracy: 0.8567 - val_loss: 0.3220
# Epoch 2/25
# 651/651 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8577 - loss: 0.3042 - val_accuracy: 0.8557 - val_loss: 0.3213
# Epoch 3/25
# 651/651 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8571 - loss: 0.3059 - val_accuracy: 0.8521 - val_loss: 0.3227
# Epoch 4/25
# 651/651 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8574 - loss: 0.3052 - val_accuracy: 0.8552 - val_loss: 0.3224
# Epoch 5/25
# 651/651 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8586 - loss: 0.3038 - val_accuracy: 0.8532 - val_loss: 0.3226
# Epoch 6/25
# 651/651 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8559 - loss: 0.3047 - val_accuracy: 0.8534 - val_loss: 0.3235
# Epoch 7/25
# 651/651 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8554 - loss: 0.3034 - val_accuracy: 0.8536 - val_loss: 0.3235
# Epoch 8/25
# ...

# %%
from sklearn.metrics import accuracy_score, mean_squared_error, r2_score

y_predp=model.predict(X_test)
y_pred=(y_predp>0.5).astype("int32")
accuracy=accuracy_score(y_test,y_pred)
mse=mean_squared_error(y_test,y_predp)
r2=r2_score(y_test,y_predp)
print(f"Accuracy:{accuracy:.4f}")
print(f"MSE:{mse:.4f}")
print(f"R² Score:{r2:.4f}")
# Out:
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Accuracy:0.8525
# MSE:0.1023
# R² Score:0.4283

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss Curves')
plt.xlabel('Epochs')
plt.ylabel('Binary Crossentropy Loss')
plt.legend()
plt.show()

# %%
input_dim = X_train.shape[1]
hidden_layers = [64, 32]
activations = ['relu', 'relu']
dropouts = [0.3, 0.2]


model = Sequential()
model.add(Dense(hidden_layers[0], input_dim=input_dim, activation=activations[0]))
if dropouts[0]: model.add(Dropout(dropouts[0]))

for i in range(1, len(hidden_layers)):
    model.add(Dense(hidden_layers[i], activation=activations[i]))
    if dropouts[i]: model.add(Dropout(dropouts[i]))

model.add(Dense(1, activation='sigmoid'))

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

history = model.fit(X_train, y_train, validation_split=0.2,epochs=25, batch_size=32,verbose=1)
# Out:
# Epoch 1/25
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 651/651 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.7684 - loss: 0.4730 - val_accuracy: 0.8423 - val_loss: 0.3412
# Epoch 2/25
# 651/651 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8338 - loss: 0.3618 - val_accuracy: 0.8469 - val_loss: 0.3301
# Epoch 3/25
# 651/651 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.8396 - loss: 0.3486 - val_accuracy: 0.8502 - val_loss: 0.3270
# Epoch 4/25
# 651/651 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8501 - loss: 0.3359 - val_accuracy: 0.8490 - val_loss: 0.3273
# Epoch 5/25
# 651/651 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8446 - loss: 0.3306 - val_accuracy: 0.8492 - val_loss: 0.3267
# ...

# %%
y_predp=model.predict(X_test)
y_pred=(y_predp>0.5).astype("int32")
accuracy=accuracy_score(y_test,y_pred)
mse=mean_squared_error(y_test,y_predp)
r2=r2_score(y_test,y_predp)
print(f"Accuracy:{accuracy:.4f}")
print(f"MSE:{mse:.4f}")
print(f"R² Score:{r2:.4f}")
# Out:
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Accuracy:0.8520
# MSE:0.1016
# R² Score:0.4325

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss Curves')
plt.xlabel('Epochs')
plt.ylabel('Binary Crossentropy Loss')
plt.legend()
plt.show()

# %%
input_dim = X_train.shape[1]
hidden_layers = [64, 32,16]
activations = ['relu', 'relu','relu']
dropouts = [0.3, 0.2,0.2]


model = Sequential()
model.add(Dense(hidden_layers[0], input_dim=input_dim, activation=activations[0]))
if dropouts[0]: model.add(Dropout(dropouts[0]))

for i in range(1, len(hidden_layers)):
    model.add(Dense(hidden_layers[i], activation=activations[i]))
    if dropouts[i]: model.add(Dropout(dropouts[i]))

model.add(Dense(1, activation='sigmoid'))

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

history = model.fit(X_train, y_train, validation_split=0.2,epochs=20, batch_size=32,verbose=1)
# Out:
# Epoch 1/20
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 651/651 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7696 - loss: 0.4801 - val_accuracy: 0.8419 - val_loss: 0.3483
# Epoch 2/20
# 651/651 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8294 - loss: 0.3705 - val_accuracy: 0.8475 - val_loss: 0.3302
# Epoch 3/20
# 651/651 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8368 - loss: 0.3548 - val_accuracy: 0.8500 - val_loss: 0.3269
# Epoch 4/20
# 651/651 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.8362 - loss: 0.3520 - val_accuracy: 0.8511 - val_loss: 0.3260
# Epoch 5/20
# 651/651 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8440 - loss: 0.3412 - val_accuracy: 0.8506 - val_loss: 0.3237
# ...

# %%
y_predp=model.predict(X_test)
y_pred=(y_predp>0.5).astype("int32")
accuracy=accuracy_score(y_test,y_pred)
mse=mean_squared_error(y_test,y_predp)
r2=r2_score(y_test,y_predp)
print(f"Accuracy:{accuracy:.4f}")
print(f"MSE:{mse:.4f}")
print(f"R² Score:{r2:.4f}")

import matplotlib.pyplot as plt
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss Curves')
plt.xlabel('Epochs')
plt.ylabel('Binary Crossentropy Loss')
plt.legend()
plt.show()
# Out:
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
# Accuracy:0.8494
# MSE:0.1022
# R² Score:0.4289
